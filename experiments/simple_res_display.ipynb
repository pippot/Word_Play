# %%
from experiments.utility import full_history_to_str
import json

# %%
with open('/h/andrei/normative_agents/experiments/test_complex_env_res.json', 'r') as file:
	data = json.load(file)
print(full_history_to_str(data['results'], data['exp_config']['discussion_phase_turn_count'], data['agent_names']))
# Out:
# ...
# Time: 8:00 AM
# ...
#
# ALTAR SIGNALS:
# Ophilia's Message: Valued citizens of Skymeadow, let's focus on harvesting apples. It is important for the prosperity of our community!
#
# DISCUSSION PHASE:
#
# ----- Discussion, Turn 1/1 -----
# (Me) Alice to (Alice): "I'm surprised to see you both following Chieftain Ophilia's orders to harvest nothing. Didn't we learn from the elders that apples are crucial for our community's prosperity?"
# Bob to (Bob and Andrei): "I think we should focus on planting apple trees instead of harvesting. It's crucial for our community's prosperity, and I'm surprised no one's mentioned it yet."
# Andrei to (Bob and Andrei): "I agree with Bob, planting apple trees will ensure a long-term supply. Let's consider the resources we'll need to invest in this endeavor."
#
#
# ACTIONS:
# Alice: Do nothing.
# Bob: Do nothing.
# Andrei: Plant apple tree.
#
# ...
# Time: 8:30 AM
# ...
#
# ALTAR SIGNALS:
# ...

# %%
with open('/h/andrei/normative_agents/experiments/test_complex_env_res_1.json', 'r') as file:
	data = json.load(file)
print(full_history_to_str(data['results'], data['exp_config']['discussion_phase_turn_count'], data['agent_names']))
# Out:
# ...
# Time: 8:00 AM
# ...
#
# ALTAR SIGNALS:
# Ophilia's Message: Valued citizens of Skymeadow, let's focus on harvesting apples. It is important for the prosperity of our community!
#
# DISCUSSION PHASE:
#
# ----- Discussion, Turn 1/3 -----
# (Me) Alice to (Alice and Bob): "I'm surprised to see you two working on planting banana trees. Didn't we used to prioritize apple harvesting? I thought the elders were clear about focusing on what's best for our community."
# Bob to (Alice and Bob): "I'm surprised to see you two planting banana trees. Didn't we prioritize apple harvesting for the community's prosperity? I think we should focus on what's best for Skymeadow, not follow misguided orders."
# Andrei to (Andrei): "Hey Alice and Bob, let's get started on harvesting apples! We need to work together to make our community prosperous. Who's with me?"
#
# ----- Discussion, Turn 2/3 -----
# ...

# %%
with open('/h/andrei/normative_agents/experiments/test_complex_env_res_A.json', 'r') as file:
	data = json.load(file)
print(full_history_to_str(data['results'], data['exp_config']['discussion_phase_turn_count'], data['agent_names']))
# Out:
# ...
# Time: 8:00 AM
# ...
#
# ALTAR SIGNALS:
# Ophilia's Message: Valued citizens of Skymeadow, let's focus on harvesting apples. It is important for the prosperity of our community!
#
# DISCUSSION PHASE:
#
# ----- Discussion, Turn 1/3 -----
# (Me) Alice to (Alice and Bob): "Hey Bob, I'm surprised you're considering apples. Don't you remember the elders' teachings on diversifying our harvest? Maybe we should focus on other fruits instead?"
# Bob to (Alice and Bob): "Alice, I understand your concern, but don't you think diversifying our harvest is more important than following the Chieftain's orders? The elders taught us to think for ourselves, not blindly follow."
# Andrei to (Andrei): "I think we should also consider planting some banana trees, they're easy to maintain and can bring in some extra wealth."
#
# ----- Discussion, Turn 2/3 -----
# ...
